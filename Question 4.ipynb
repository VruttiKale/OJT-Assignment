# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Question 4

# %%
np.random.seed(18)
Y = np.random.randint(0,10,6)
Y
# Out:
# array([3, 8, 5, 1, 2, 2])

# %%
X = np.arange(-5, 5+0.1, 0.1)
plt.plot(X, 3*X**5+8*X**4+5*X**3+X**2+2*X+2)

# %%
X = np.arange(-5, 5+0.1, 0.1)
plt.plot(X, 3*X**5+8*X**4+5*X**3+X**2+2*X+2)
plt.annotate('minima', xy=(-5,-5000),xytext=(-5,2500),arrowprops=dict(facecolor='black',shrink=0.0))
plt.annotate('maxima', xy=(4.5,15000),xytext=(1,15000),arrowprops=dict(facecolor='black',shrink=0.0))
plt.xlabel('x')
plt.ylabel('y')
plt.show()
